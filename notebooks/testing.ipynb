# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # dummy test

# %%
x = np.arange(10)
y = x**2 + 10

fig, ax = plt.subplots(figsize=(10,5))
ax.set_xticks([1.5, 0.5, 8], minor=False)
ax.plot(x, y)

ax.xaxis.grid()
plt.show()
