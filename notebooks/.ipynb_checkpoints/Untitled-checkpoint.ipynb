# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')
from oem_functions import linear_oem_sp

# %% [markdown]
# # dummy test

# %%
x = np.arange(10)
y = x**2 + 10

plt.figure(figsize=(10,5))
plt.plot(x, y)
plt.show()
